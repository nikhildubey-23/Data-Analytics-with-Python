# %%
# %matplotlib inline
from matplotlib import pyplot as plt
#for to give heading we use title method 
plt.title("heading and lebeling")
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
x = [1,2,3,4,5,6]
y = [1,2,3,4,5,6]
plt.plot(x,y)
plt.show()
