# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data using NumPy
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot the data
plt.plot(x, y, label='sin(x)')

# Add text at a specific location
plt.text(5,1, 'Example Text', fontsize=16, color='blue')

# Customize the plot
plt.title('Plot with Text')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add legend
plt.legend()

# Show the plot
plt.show()
